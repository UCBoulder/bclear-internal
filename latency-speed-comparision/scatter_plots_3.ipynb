# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as dates
import json
import io

# %% [markdown]
# ## Idle latency vs Average download speed (Jan 2011 - Jul 2023)

# %% [markdown]
# ### weekly data

# %%
latency = pd.read_csv("data_rtt_max_week/Average of Idle latency.csv")
speed = pd.read_csv("data_rtt_max_week/Average download speed.csv")
merge_df = pd.merge(speed, latency, how="left", on="dtime per week")
merge_df.tail()
# Out:
#     dtime per week  Average speed (Mbps)  Average latency (ms)
# 653     2023-07-03               284.496                34.005
# 654     2023-07-10               287.265                34.012
# 655     2023-07-17               291.132                33.686
# 656     2023-07-24               289.712                33.954
# 657     2023-07-31               289.100                33.680

# %%
# Calculate fit line
x = merge_df["Average speed (Mbps)"]
y = merge_df["Average latency (ms)"]
# idx = np.isfinite(x) & np.isfinite(y)
# up_trend = np.polyfit(x[idx], y[idx], 3)
# up_fit = np.poly1d(up_trend)

plt.figure(figsize=(12,3))
sns.set_theme(style="whitegrid")
plt.scatter(x, y, s=3.5)
# plt.plot(x, up_fit(x), "r--", label="Upstream Trend")
plt.xlabel('Download speed (Mbps)')
plt.ylabel('Idle latency rtt_max (ms)')
plt.show()

# %% [markdown]
# ### 30th July 2023 only

# %%
latency = pd.read_csv("data/Average of Idle latency.csv")
speed = pd.read_csv("data/Average download speed.csv")
merge_df = pd.merge(speed, latency, how="left", on="dtime per minute")
merge_df.tail()
# Out:
#      dtime per minute  Average speed (Mbps)  Average latency (ms)
# 1435            23:55               443.908                28.974
# 1436            23:56               308.923                34.280
# 1437            23:57               302.758                29.941
# 1438            23:58               305.123                35.848
# 1439            23:59               157.147                23.898

# %%
# Calculate fit line
x = merge_df["Average speed (Mbps)"]
y = merge_df["Average latency (ms)"]
# idx = np.isfinite(x) & np.isfinite(y)
# up_trend = np.polyfit(x[idx], y[idx], 3)
# up_fit = np.poly1d(up_trend)

plt.figure(figsize=(12,3))
sns.set_theme(style="whitegrid")
plt.scatter(x, y, s=3.5)
# plt.plot(x, up_fit(x), "r--", label="Upstream Trend")
plt.xlabel('Download speed (Mbps)')
plt.ylabel('Idle latency rtt_max (ms)')
plt.show()

# %% [markdown]
# ## Idle latency vs Average upload speed (Jan 2011 - Jul 2023)

# %% [markdown]
# ### weekly data

# %%
latency = pd.read_csv("data_rtt_max_week/Average of Idle latency.csv")
speed = pd.read_csv("data_rtt_max_week/Average upload speed.csv")
merge_df = pd.merge(speed, latency, how="left", on="dtime per week")
merge_df.tail()
# Out:
#     dtime per week  Average speed (Mbps)  Average latency (ms)
# 653     2023-07-03               141.963                34.005
# 654     2023-07-10               141.638                34.012
# 655     2023-07-17               143.087                33.686
# 656     2023-07-24               142.339                33.954
# 657     2023-07-31               140.593                33.680

# %%
# Calculate fit line
x = merge_df["Average speed (Mbps)"]
y = merge_df["Average latency (ms)"]
# idx = np.isfinite(x) & np.isfinite(y)
# up_trend = np.polyfit(x[idx], y[idx], 3)
# up_fit = np.poly1d(up_trend)

plt.figure(figsize=(12,3))
sns.set_theme(style="whitegrid")
plt.scatter(x, y, s=3.5)
# plt.plot(x, up_fit(x), "r--", label="Upstream Trend")
plt.xlabel('Upload speed (Mbps)')
plt.ylabel('Idle latency rtt_max (ms)')
plt.show()

# %% [markdown]
# ### 30th July 2023 only

# %%
latency = pd.read_csv("data/Average of Idle latency.csv")
speed = pd.read_csv("data/Average upload speed.csv")
merge_df = pd.merge(speed, latency, how="left", on="dtime per minute")
merge_df.tail()
# Out:
#      dtime per minute  Average speed (Mbps)  Average latency (ms)
# 1435            23:55               135.230                28.974
# 1436            23:56               247.009                34.280
# 1437            23:57               134.885                29.941
# 1438            23:58                85.321                35.848
# 1439            23:59                22.286                23.898

# %%
# Calculate fit line
x = merge_df["Average speed (Mbps)"]
y = merge_df["Average latency (ms)"]
# idx = np.isfinite(x) & np.isfinite(y)
# up_trend = np.polyfit(x[idx], y[idx], 3)
# up_fit = np.poly1d(up_trend)

plt.figure(figsize=(12,3))
sns.set_theme(style="whitegrid")
plt.scatter(x, y, s=3.5)
# plt.plot(x, up_fit(x), "r--", label="Upstream Trend")
plt.xlabel('Upload speed (Mbps)')
plt.ylabel('Idle latency rtt_max (ms)')
plt.show()

# %% [markdown]
# ## Downstream LUL vs Average download speed (Jan 2011 - Jul 2023)

# %% [markdown]
# ### weekly data

# %%
latency = pd.read_csv("data_rtt_max_week/Average of downstream LUL.csv")
speed = pd.read_csv("data_rtt_max_week/Average download speed.csv")
merge_df = pd.merge(speed, latency, how="left", on="dtime per week")
merge_df.tail()
# Out:
#     dtime per week  Average speed (Mbps)  Average latency (ms)
# 653     2023-07-03               284.496               128.557
# 654     2023-07-10               287.265               129.977
# 655     2023-07-17               291.132               129.722
# 656     2023-07-24               289.712               130.518
# 657     2023-07-31               289.100               131.230

# %%
# Calculate fit line
x = merge_df["Average speed (Mbps)"]
y = merge_df["Average latency (ms)"]
# idx = np.isfinite(x) & np.isfinite(y)
# up_trend = np.polyfit(x[idx], y[idx], 3)
# up_fit = np.poly1d(up_trend)

plt.figure(figsize=(12,3))
sns.set_theme(style="whitegrid")
plt.scatter(x, y, s=3.5)
# plt.plot(x, up_fit(x), "r--", label="Upstream Trend")
plt.xlabel('Download speed (Mbps)')
plt.ylabel('Idle latency rtt_max (ms)')
plt.show()

# %% [markdown]
# ### 30th July 2023 only

# %%
latency = pd.read_csv("data/Average of downstream LUL.csv")
speed = pd.read_csv("data/Average download speed.csv")
merge_df = pd.merge(speed, latency, how="left", on="dtime per minute")
merge_df.tail()
# Out:
#      dtime per minute  Average speed (Mbps)  Average latency (ms)
# 1435            23:55               443.908               103.431
# 1436            23:56               308.923                90.015
# 1437            23:57               302.758               138.699
# 1438            23:58               305.123                75.107
# 1439            23:59               157.147                   NaN

# %%
# Calculate fit line
x = merge_df["Average speed (Mbps)"]
y = merge_df["Average latency (ms)"]
# idx = np.isfinite(x) & np.isfinite(y)
# up_trend = np.polyfit(x[idx], y[idx], 3)
# up_fit = np.poly1d(up_trend)

plt.figure(figsize=(12,3))
sns.set_theme(style="whitegrid")
plt.scatter(x, y, s=3.5)
# plt.plot(x, up_fit(x), "r--", label="Upstream Trend")
plt.xlabel('Download speed (Mbps)')
plt.ylabel('Idle latency rtt_max (ms)')
plt.show()

# %% [markdown]
# ## Upstream LUL vs Average upload speed (Jan 2011 - Jul 2023)

# %% [markdown]
# ### weekly data

# %%
latency = pd.read_csv("data_rtt_max_week/Average of Upstream LUL.csv")
speed = pd.read_csv("data_rtt_max_week/Average upload speed.csv")
merge_df = pd.merge(speed, latency, how="left", on="dtime per week")
merge_df['Average latency (ms)'] = merge_df['Average latency (ms)'].str.replace(",","").astype(float)
merge_df.tail()
# Out:
#     dtime per week  Average speed (Mbps)  Average latency (ms)
# 653     2023-07-03               141.963               226.878
# 654     2023-07-10               141.638               227.011
# 655     2023-07-17               143.087               220.248
# 656     2023-07-24               142.339               220.734
# 657     2023-07-31               140.593               222.528

# %%
plt.figure(figsize=(12,3))
sns.set_theme(style="whitegrid")
plt.scatter(merge_df["Average speed (Mbps)"], merge_df["Average latency (ms)"], s=3.5)
plt.xlabel('Upload speed (Mbps)')
plt.ylabel('Upstream LUL rtt_max (ms)')
plt.show()

# %% [markdown]
# ### 30th July 2023 only

# %%
latency = pd.read_csv("data/Average of upstream LUL.csv")
speed = pd.read_csv("data/Average upload speed.csv")
merge_df = pd.merge(speed, latency, how="left", on="dtime per minute")
merge_df.tail()
# Out:
#      dtime per minute  Average speed (Mbps)  Average latency (ms)
# 1435            23:55               135.230               283.703
# 1436            23:56               247.009               147.415
# 1437            23:57               134.885               152.386
# 1438            23:58                85.321               385.917
# 1439            23:59                22.286                   NaN

# %%
# Calculate fit line
x = merge_df["Average speed (Mbps)"]
y = merge_df["Average latency (ms)"]
# idx = np.isfinite(x) & np.isfinite(y)
# up_trend = np.polyfit(x[idx], y[idx], 3)
# up_fit = np.poly1d(up_trend)

plt.figure(figsize=(12,3))
sns.set_theme(style="whitegrid")
plt.scatter(x, y, s=3.5)
# plt.plot(x, up_fit(x), "r--", label="Upstream Trend")
plt.xlabel('Upload speed (Mbps)')
plt.ylabel('Idle latency rtt_max (ms)')
plt.show()

# %% [markdown]
# # Cable

# %% [markdown]
# ## Idle latency vs Average download speed for Cable (Jan 2011 - Jul 2023)

# %%
latency = pd.read_csv("data_rtt_max_week/Average of Idle latency-Cable.csv")
speed = pd.read_csv("data_rtt_max_week/Average download speed-Cable.csv")
merge_df = pd.merge(speed, latency, how="left", on="dtime per week")
merge_df.tail()
# Out:
#     dtime per week  Average speed (Mbps)  Average latency (ms)
# 653     2023-07-03               336.506                32.226
# 654     2023-07-10               339.449                32.279
# 655     2023-07-17               344.017                31.986
# 656     2023-07-24               342.492                32.169
# 657     2023-07-31               341.437                32.113

# %%
plt.figure(figsize=(12,3))
sns.set_theme(style="whitegrid")
plt.scatter(merge_df["Average speed (Mbps)"], merge_df["Average latency (ms)"], s=3.5)
plt.xlabel('Download speed (Mbps)')
plt.ylabel('Idle latency rtt_max (ms)')
plt.show()

# %% [markdown]
# ## Idle latency vs Average upload speed for Cable (Jan 2011 - Jul 2023)

# %%
latency = pd.read_csv("data_rtt_max_week/Average of Idle latency-Cable.csv")
speed = pd.read_csv("data_rtt_max_week/Average upload speed-Cable.csv")
merge_df = pd.merge(speed, latency, how="left", on="dtime per week")
merge_df.tail()
# Out:
#     dtime per week  Average speed (Mbps)  Average latency (ms)
# 653     2023-07-03                53.261                32.226
# 654     2023-07-10                54.105                32.279
# 655     2023-07-17                53.791                31.986
# 656     2023-07-24                54.234                32.169
# 657     2023-07-31                53.797                32.113

# %%
plt.figure(figsize=(12,3))
sns.set_theme(style="whitegrid")
plt.scatter(merge_df["Average speed (Mbps)"], merge_df["Average latency (ms)"], s=3.5)
plt.xlabel('Upload speed (Mbps)')
plt.ylabel('Idle latency rtt_max (ms)')
plt.show()

# %% [markdown]
# ## Downstream LUL vs Average download speed for Cable (Jan 2011 - Jul 2023)

# %%
latency = pd.read_csv("data_rtt_max_week/Average of downstream LUL-Cable.csv")
speed = pd.read_csv("data_rtt_max_week/Average download speed-Cable.csv")
merge_df = pd.merge(speed, latency, how="left", on="dtime per week")
merge_df.tail()
# Out:
#     dtime per week  Average speed (Mbps)  Average latency (ms)
# 653     2023-07-03               336.506               121.209
# 654     2023-07-10               339.449               123.247
# 655     2023-07-17               344.017               122.173
# 656     2023-07-24               342.492               121.822
# 657     2023-07-31               341.437               124.827

# %%
plt.figure(figsize=(12,3))
sns.set_theme(style="whitegrid")
plt.scatter(merge_df["Average speed (Mbps)"], merge_df["Average latency (ms)"], s=3.5)
plt.xlabel('Download speed (Mbps)')
plt.ylabel('Downstream LUL rtt_max (ms)')
plt.show()

# %% [markdown]
# ## Upstream LUL vs Average upload speed for Cable (Jan 2011 - Jul 2023)

# %%
latency = pd.read_csv("data_rtt_max_week/Average of Upstream LUL-Cable.csv")
speed = pd.read_csv("data_rtt_max_week/Average upload speed-Cable.csv")
merge_df = pd.merge(speed, latency, how="left", on="dtime per week")
merge_df['Average latency (ms)'] = merge_df['Average latency (ms)'].str.replace(",","").astype(float)
merge_df.tail()
# Out:
#     dtime per week  Average speed (Mbps)  Average latency (ms)
# 653     2023-07-03                53.261               232.028
# 654     2023-07-10                54.105               230.025
# 655     2023-07-17                53.791               215.897
# 656     2023-07-24                54.234               219.909
# 657     2023-07-31                53.797               222.968

# %%
plt.figure(figsize=(12,3))
sns.set_theme(style="whitegrid")
plt.scatter(merge_df["Average speed (Mbps)"], merge_df["Average latency (ms)"], s=3.5)
plt.xlabel('Upload speed (Mbps)')
plt.ylabel('Upstream LUL rtt_max (ms)')
plt.show()

# %% [markdown]
# # Fiber

# %% [markdown]
# ## Idle latency vs Average download speed for Fiber (Jan 2011 - Jul 2023)

# %%
latency = pd.read_csv("data_rtt_max_week/Average of Idle latency-Fiber.csv")
speed = pd.read_csv("data_rtt_max_week/Average download speed-Fiber.csv")
merge_df = pd.merge(speed, latency, how="left", on="dtime per week")
merge_df.tail()
# Out:
#     dtime per week  Average speed (Mbps)  Average latency (ms)
# 653     2023-07-03               447.070                17.196
# 654     2023-07-10               448.340                17.649
# 655     2023-07-17               450.735                17.034
# 656     2023-07-24               449.729                17.158
# 657     2023-07-31               447.665                16.762

# %%
plt.figure(figsize=(12,3))
sns.set_theme(style="whitegrid")
plt.scatter(merge_df["Average speed (Mbps)"], merge_df["Average latency (ms)"], s=3.5)
plt.xlabel('Download speed (Mbps)')
plt.ylabel('Idle latency rtt_max (ms)')
plt.show()

# %% [markdown]
# ## Idle latency vs Average upload speed for Fiber (Jan 2011 - Jul 2023)

# %%
latency = pd.read_csv("data_rtt_max_week/Average of Idle latency-Fiber.csv")
speed = pd.read_csv("data_rtt_max_week/Average upload speed-Fiber.csv")
merge_df = pd.merge(speed, latency, how="left", on="dtime per week")
merge_df.tail()
# Out:
#     dtime per week  Average speed (Mbps)  Average latency (ms)
# 653     2023-07-03               403.063                17.196
# 654     2023-07-10               401.844                17.649
# 655     2023-07-17               405.449                17.034
# 656     2023-07-24               403.540                17.158
# 657     2023-07-31               398.890                16.762

# %%
plt.figure(figsize=(12,3))
sns.set_theme(style="whitegrid")
plt.scatter(merge_df["Average speed (Mbps)"], merge_df["Average latency (ms)"], s=3.5)
plt.xlabel('Upload speed (Mbps)')
plt.ylabel('Idle latency rtt_max (ms)')
plt.show()

# %% [markdown]
# ## Downstream LUL vs Average download speed for Fiber (Jan 2011 - Jul 2023)

# %%
latency = pd.read_csv("data_rtt_max_week/Average of downstream LUL-Fiber.csv")
speed = pd.read_csv("data_rtt_max_week/Average download speed-Fiber.csv")
merge_df = pd.merge(speed, latency, how="left", on="dtime per week")
merge_df.tail()
# Out:
#     dtime per week  Average speed (Mbps)  Average latency (ms)
# 653     2023-07-03               447.070                73.983
# 654     2023-07-10               448.340                75.403
# 655     2023-07-17               450.735                77.674
# 656     2023-07-24               449.729                74.991
# 657     2023-07-31               447.665                70.493

# %%
plt.figure(figsize=(12,3))
sns.set_theme(style="whitegrid")
plt.scatter(merge_df["Average speed (Mbps)"], merge_df["Average latency (ms)"], s=3.5)
plt.xlabel('Download speed (Mbps)')
plt.ylabel('Downstream LUL rtt_max (ms)')
plt.show()

# %% [markdown]
# ## Upstream LUL vs Average upload speed for Fiber (Jan 2011 - Jul 2023)

# %%
latency = pd.read_csv("data_rtt_max_week/Average of Upstream LUL-Fiber.csv")
speed = pd.read_csv("data_rtt_max_week/Average upload speed-Fiber.csv")
merge_df = pd.merge(speed, latency, how="left", on="dtime per week")
merge_df.tail()
# Out:
#     dtime per week  Average speed (Mbps)  Average latency (ms)
# 653     2023-07-03               403.063                62.519
# 654     2023-07-10               401.844                65.831
# 655     2023-07-17               405.449                67.293
# 656     2023-07-24               403.540                68.836
# 657     2023-07-31               398.890                65.996

# %%
plt.figure(figsize=(12,3))
sns.set_theme(style="whitegrid")
plt.scatter(merge_df["Average speed (Mbps)"], merge_df["Average latency (ms)"], s=3.5)
plt.xlabel('Upload speed (Mbps)')
plt.ylabel('Upstream LUL rtt_max (ms)')
plt.show()

# %% [markdown]
# # DSL

# %% [markdown]
# ## Idle latency vs Average download speed for DSL (Jan 2011 - Jul 2023)

# %%
latency = pd.read_csv("data_rtt_max_week/Average of Idle latency-DSL.csv")
speed = pd.read_csv("data_rtt_max_week/Average download speed-DSL.csv")
merge_df = pd.merge(speed, latency, how="left", on="dtime per week")
merge_df.tail()
# Out:
#     dtime per week  Average speed (Mbps)  Average latency (ms)
# 653     2023-07-03                77.444                50.740
# 654     2023-07-10                78.943                50.259
# 655     2023-07-17                79.936                50.283
# 656     2023-07-24                80.485                50.924
# 657     2023-07-31                82.046                50.397

# %%
plt.figure(figsize=(12,3))
sns.set_theme(style="whitegrid")
plt.scatter(merge_df["Average speed (Mbps)"], merge_df["Average latency (ms)"], s=3.5)
plt.xlabel('Download speed (Mbps)')
plt.ylabel('Idle latency rtt_max (ms)')
plt.show()

# %% [markdown]
# ## Idle latency vs Average upload speed for DSL (Jan 2011 - Jul 2023)

# %%
latency = pd.read_csv("data_rtt_max_week/Average of Idle latency-DSL.csv")
speed = pd.read_csv("data_rtt_max_week/Average upload speed-DSL.csv")
merge_df = pd.merge(speed, latency, how="left", on="dtime per week")
merge_df.tail()
# Out:
#     dtime per week  Average speed (Mbps)  Average latency (ms)
# 653     2023-07-03                44.844                50.740
# 654     2023-07-10                45.375                50.259
# 655     2023-07-17                45.642                50.283
# 656     2023-07-24                46.434                50.924
# 657     2023-07-31                47.243                50.397

# %%
plt.figure(figsize=(12,3))
sns.set_theme(style="whitegrid")
plt.scatter(merge_df["Average speed (Mbps)"], merge_df["Average latency (ms)"], s=3.5)
plt.xlabel('Upload speed (Mbps)')
plt.ylabel('Idle latency rtt_max (ms)')
plt.show()

# %% [markdown]
# ## Downstream LUL vs Average download speed for DSL (Jan 2011 - Jul 2023)

# %%
latency = pd.read_csv("data_rtt_max_week/Average of downstream LUL-DSL.csv")
speed = pd.read_csv("data_rtt_max_week/Average download speed-DSL.csv")
merge_df = pd.merge(speed, latency, how="left", on="dtime per week")
merge_df.tail()
# Out:
#     dtime per week  Average speed (Mbps)  Average latency (ms)
# 653     2023-07-03                77.444               195.358
# 654     2023-07-10                78.943               195.384
# 655     2023-07-17                79.936               194.873
# 656     2023-07-24                80.485               201.826
# 657     2023-07-31                82.046               203.208

# %%
plt.figure(figsize=(12,3))
sns.set_theme(style="whitegrid")
plt.scatter(merge_df["Average speed (Mbps)"], merge_df["Average latency (ms)"], s=3.5)
plt.xlabel('Download speed (Mbps)')
plt.ylabel('Downstream LUL rtt_max (ms)')
plt.show()

# %% [markdown]
# ## Upstream LUL vs Average upload speed for DSL (Jan 2011 - Jul 2023)

# %%
latency = pd.read_csv("data_rtt_max_week/Average of Upstream LUL-DSL.csv")
speed = pd.read_csv("data_rtt_max_week/Average upload speed-DSL.csv")
merge_df = pd.merge(speed, latency, how="left", on="dtime per week")
merge_df['Average latency (ms)'] = merge_df['Average latency (ms)'].str.replace(",","").astype(float)
merge_df.tail()
# Out:
#     dtime per week  Average speed (Mbps)  Average latency (ms)
# 653     2023-07-03                44.844               460.294
# 654     2023-07-10                45.375               459.920
# 655     2023-07-17                45.642               461.436
# 656     2023-07-24                46.434               455.166
# 657     2023-07-31                47.243               456.977

# %%
plt.figure(figsize=(12,3))
sns.set_theme(style="whitegrid")
plt.scatter(merge_df["Average speed (Mbps)"], merge_df["Average latency (ms)"], s=3.5)
plt.xlabel('Upload speed (Mbps)')
plt.ylabel('Upstream LUL rtt_max (ms)')
plt.show()
