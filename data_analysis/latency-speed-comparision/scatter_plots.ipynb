# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as dates
import json
import io

# %% [markdown]
# ## Idle latency vs Average download speed (Jan 2011 - Jul 2023)

# %%
latency = pd.read_csv("data/Average of Idle latency.csv")
speed = pd.read_csv("data/Average download speed.csv")
merge_df = pd.merge(speed, latency, how="left", on="dtime per week")
merge_df.tail()
# Out:
#     dtime per week  Average speed (Mbps)  Average latency (ms)
# 653     2023-07-03               284.496                21.079
# 654     2023-07-10               287.265                20.938
# 655     2023-07-17               291.132                20.926
# 656     2023-07-24               289.712                21.014
# 657     2023-07-31               289.100                20.732

# %%
# Calculate fit line
x = merge_df["Average speed (Mbps)"]
y = merge_df["Average latency (ms)"]
# idx = np.isfinite(x) & np.isfinite(y)
# up_trend = np.polyfit(x[idx], y[idx], 3)
# up_fit = np.poly1d(up_trend)

plt.figure(figsize=(12,3))
sns.set_theme(style="whitegrid")
plt.scatter(x, y, s=3.5)
# plt.plot(x, up_fit(x), "r--", label="Upstream Trend")
plt.xlabel('Download speed (Mbps)')
plt.ylabel('Idle latency rtt_avg (ms)')
plt.show()

# %% [markdown]
# ## Idle latency vs Average upload speed (Jan 2011 - Jul 2023)

# %%
latency = pd.read_csv("data/Average of Idle latency.csv")
speed = pd.read_csv("data/Average upload speed.csv")
merge_df = pd.merge(speed, latency, how="left", on="dtime per week")
merge_df.tail()
# Out:
#     dtime per week  Average speed (Mbps)  Average latency (ms)
# 653     2023-07-03               141.963                21.079
# 654     2023-07-10               141.638                20.938
# 655     2023-07-17               143.087                20.926
# 656     2023-07-24               142.339                21.014
# 657     2023-07-31               140.593                20.732

# %%
# Calculate fit line
x = merge_df["Average speed (Mbps)"]
y = merge_df["Average latency (ms)"]
# idx = np.isfinite(x) & np.isfinite(y)
# up_trend = np.polyfit(x[idx], y[idx], 3)
# up_fit = np.poly1d(up_trend)

plt.figure(figsize=(12,3))
sns.set_theme(style="whitegrid")
plt.scatter(x, y, s=3.5)
# plt.plot(x, up_fit(x), "r--", label="Upstream Trend")
plt.xlabel('Upload speed (Mbps)')
plt.ylabel('Idle latency rtt_avg (ms)')
plt.show()

# %% [markdown]
# ## Downstream LUL vs Average download speed (Jan 2011 - Jul 2023)

# %%
latency = pd.read_csv("data/Average of downstream LUL.csv")
speed = pd.read_csv("data/Average download speed.csv")
merge_df = pd.merge(speed, latency, how="left", on="dtime per week")
merge_df.tail()
# Out:
#     dtime per week  Average speed (Mbps)  Average latency (ms)
# 653     2023-07-03               284.496                73.243
# 654     2023-07-10               287.265                73.555
# 655     2023-07-17               291.132                73.707
# 656     2023-07-24               289.712                74.132
# 657     2023-07-31               289.100                73.605

# %%
# Calculate fit line
x = merge_df["Average speed (Mbps)"]
y = merge_df["Average latency (ms)"]
# idx = np.isfinite(x) & np.isfinite(y)
# up_trend = np.polyfit(x[idx], y[idx], 3)
# up_fit = np.poly1d(up_trend)

plt.figure(figsize=(12,3))
sns.set_theme(style="whitegrid")
plt.scatter(x, y, s=3.5)
# plt.plot(x, up_fit(x), "r--", label="Upstream Trend")
plt.xlabel('Download speed (Mbps)')
plt.ylabel('Idle latency rtt_avg (ms)')
plt.show()

# %% [markdown]
# ## Upstream LUL vs Average upload speed (Jan 2011 - Jul 2023)

# %%
latency = pd.read_csv("data/Average of Upstream LUL.csv")
speed = pd.read_csv("data/Average upload speed.csv")
merge_df = pd.merge(speed, latency, how="left", on="dtime per week")
merge_df.tail()
# Out:
#     dtime per week  Average speed (Mbps)  Average latency (ms)
# 653     2023-07-03               141.963               128.814
# 654     2023-07-10               141.638               127.920
# 655     2023-07-17               143.087               124.296
# 656     2023-07-24               142.339               124.074
# 657     2023-07-31               140.593               124.350

# %%
plt.figure(figsize=(12,3))
sns.set_theme(style="whitegrid")
plt.scatter(merge_df["Average speed (Mbps)"], merge_df["Average latency (ms)"], s=3.5)
plt.xlabel('Upload speed (Mbps)')
plt.ylabel('Upstream LUL rtt_avg (ms)')
plt.show()

# %% [markdown]
# # Cable

# %% [markdown]
# ## Idle latency vs Average download speed for Cable (Jan 2011 - Jul 2023)

# %%
latency = pd.read_csv("data/Average of Idle latency-Cable.csv")
speed = pd.read_csv("data/Average download speed-Cable.csv")
merge_df = pd.merge(speed, latency, how="left", on="dtime per week")
merge_df.tail()
# Out:
#     dtime per week  Average speed (Mbps)  Average latency (ms)
# 653     2023-07-03               336.506                19.415
# 654     2023-07-10               339.449                19.281
# 655     2023-07-17               344.017                19.343
# 656     2023-07-24               342.492                19.457
# 657     2023-07-31               341.437                19.345

# %%
plt.figure(figsize=(12,3))
sns.set_theme(style="whitegrid")
plt.scatter(merge_df["Average speed (Mbps)"], merge_df["Average latency (ms)"], s=3.5)
plt.xlabel('Download speed (Mbps)')
plt.ylabel('Idle latency rtt_avg (ms)')
plt.show()

# %% [markdown]
# ## Idle latency vs Average upload speed for Cable (Jan 2011 - Jul 2023)

# %%
latency = pd.read_csv("data/Average of Idle latency-Cable.csv")
speed = pd.read_csv("data/Average upload speed-Cable.csv")
merge_df = pd.merge(speed, latency, how="left", on="dtime per week")
merge_df.tail()
# Out:
#     dtime per week  Average speed (Mbps)  Average latency (ms)
# 653     2023-07-03                53.261                19.415
# 654     2023-07-10                54.105                19.281
# 655     2023-07-17                53.791                19.343
# 656     2023-07-24                54.234                19.457
# 657     2023-07-31                53.797                19.345

# %%
plt.figure(figsize=(12,3))
sns.set_theme(style="whitegrid")
plt.scatter(merge_df["Average speed (Mbps)"], merge_df["Average latency (ms)"], s=3.5)
plt.xlabel('Upload speed (Mbps)')
plt.ylabel('Idle latency rtt_avg (ms)')
plt.show()

# %% [markdown]
# ## Downstream LUL vs Average download speed for Cable (Jan 2011 - Jul 2023)

# %%
latency = pd.read_csv("data/Average of downstream LUL-Cable.csv")
speed = pd.read_csv("data/Average download speed-Cable.csv")
merge_df = pd.merge(speed, latency, how="left", on="dtime per week")
merge_df.tail()
# Out:
#     dtime per week  Average speed (Mbps)  Average latency (ms)
# 653     2023-07-03               336.506                61.912
# 654     2023-07-10               339.449                62.610
# 655     2023-07-17               344.017                62.423
# 656     2023-07-24               342.492                61.874
# 657     2023-07-31               341.437                62.423

# %%
plt.figure(figsize=(12,3))
sns.set_theme(style="whitegrid")
plt.scatter(merge_df["Average speed (Mbps)"], merge_df["Average latency (ms)"], s=3.5)
plt.xlabel('Download speed (Mbps)')
plt.ylabel('Downstream LUL rtt_avg (ms)')
plt.show()

# %% [markdown]
# ## Upstream LUL vs Average upload speed for Cable (Jan 2011 - Jul 2023)

# %%
latency = pd.read_csv("data/Average of Upstream LUL-Cable.csv")
speed = pd.read_csv("data/Average upload speed-Cable.csv")
merge_df = pd.merge(speed, latency, how="left", on="dtime per week")
merge_df.tail()
# Out:
#     dtime per week  Average speed (Mbps)  Average latency (ms)
# 653     2023-07-03                53.261               102.661
# 654     2023-07-10                54.105                99.968
# 655     2023-07-17                53.791                92.688
# 656     2023-07-24                54.234                95.469
# 657     2023-07-31                53.797                96.668

# %%
plt.figure(figsize=(12,3))
sns.set_theme(style="whitegrid")
plt.scatter(merge_df["Average speed (Mbps)"], merge_df["Average latency (ms)"], s=3.5)
plt.xlabel('Upload speed (Mbps)')
plt.ylabel('Upstream LUL rtt_avg (ms)')
plt.show()

# %% [markdown]
# # Fiber

# %% [markdown]
# ## Idle latency vs Average download speed for Fiber (Jan 2011 - Jul 2023)

# %%
latency = pd.read_csv("data/Average of Idle latency-Fiber.csv")
speed = pd.read_csv("data/Average download speed-Fiber.csv")
merge_df = pd.merge(speed, latency, how="left", on="dtime per week")
merge_df.tail()
# Out:
#     dtime per week  Average speed (Mbps)  Average latency (ms)
# 653     2023-07-03               447.070                11.887
# 654     2023-07-10               448.340                11.899
# 655     2023-07-17               450.735                11.778
# 656     2023-07-24               449.729                11.701
# 657     2023-07-31               447.665                11.565

# %%
plt.figure(figsize=(12,3))
sns.set_theme(style="whitegrid")
plt.scatter(merge_df["Average speed (Mbps)"], merge_df["Average latency (ms)"], s=3.5)
plt.xlabel('Download speed (Mbps)')
plt.ylabel('Idle latency rtt_avg (ms)')
plt.show()

# %% [markdown]
# ## Idle latency vs Average upload speed for Fiber (Jan 2011 - Jul 2023)

# %%
latency = pd.read_csv("data/Average of Idle latency-Fiber.csv")
speed = pd.read_csv("data/Average upload speed-Fiber.csv")
merge_df = pd.merge(speed, latency, how="left", on="dtime per week")
merge_df.tail()
# Out:
#     dtime per week  Average speed (Mbps)  Average latency (ms)
# 653     2023-07-03               403.063                11.887
# 654     2023-07-10               401.844                11.899
# 655     2023-07-17               405.449                11.778
# 656     2023-07-24               403.540                11.701
# 657     2023-07-31               398.890                11.565

# %%
plt.figure(figsize=(12,3))
sns.set_theme(style="whitegrid")
plt.scatter(merge_df["Average speed (Mbps)"], merge_df["Average latency (ms)"], s=3.5)
plt.xlabel('Upload speed (Mbps)')
plt.ylabel('Idle latency rtt_avg (ms)')
plt.show()

# %% [markdown]
# ## Downstream LUL vs Average download speed for Fiber (Jan 2011 - Jul 2023)

# %%
latency = pd.read_csv("data/Average of downstream LUL-Fiber.csv")
speed = pd.read_csv("data/Average download speed-Fiber.csv")
merge_df = pd.merge(speed, latency, how="left", on="dtime per week")
merge_df.tail()
# Out:
#     dtime per week  Average speed (Mbps)  Average latency (ms)
# 653     2023-07-03               447.070                40.226
# 654     2023-07-10               448.340                40.644
# 655     2023-07-17               450.735                41.500
# 656     2023-07-24               449.729                40.478
# 657     2023-07-31               447.665                38.386

# %%
plt.figure(figsize=(12,3))
sns.set_theme(style="whitegrid")
plt.scatter(merge_df["Average speed (Mbps)"], merge_df["Average latency (ms)"], s=3.5)
plt.xlabel('Download speed (Mbps)')
plt.ylabel('Downstream LUL rtt_avg (ms)')
plt.show()

# %% [markdown]
# ## Upstream LUL vs Average upload speed for Fiber (Jan 2011 - Jul 2023)

# %%
latency = pd.read_csv("data/Average of Upstream LUL-Fiber.csv")
speed = pd.read_csv("data/Average upload speed-Fiber.csv")
merge_df = pd.merge(speed, latency, how="left", on="dtime per week")
merge_df.tail()
# Out:
#     dtime per week  Average speed (Mbps)  Average latency (ms)
# 653     2023-07-03               403.063                39.096
# 654     2023-07-10               401.844                39.957
# 655     2023-07-17               405.449                40.503
# 656     2023-07-24               403.540                42.014
# 657     2023-07-31               398.890                40.166

# %%
plt.figure(figsize=(12,3))
sns.set_theme(style="whitegrid")
plt.scatter(merge_df["Average speed (Mbps)"], merge_df["Average latency (ms)"], s=3.5)
plt.xlabel('Upload speed (Mbps)')
plt.ylabel('Upstream LUL rtt_avg (ms)')
plt.show()

# %% [markdown]
# # DSL

# %% [markdown]
# ## Idle latency vs Average download speed for DSL (Jan 2011 - Jul 2023)

# %%
latency = pd.read_csv("data/Average of Idle latency-DSL.csv")
speed = pd.read_csv("data/Average download speed-DSL.csv")
merge_df = pd.merge(speed, latency, how="left", on="dtime per week")
merge_df.tail()
# Out:
#     dtime per week  Average speed (Mbps)  Average latency (ms)
# 653     2023-07-03                77.444                31.208
# 654     2023-07-10                78.943                30.913
# 655     2023-07-17                79.936                30.982
# 656     2023-07-24                80.485                31.242
# 657     2023-07-31                82.046                30.571

# %%
plt.figure(figsize=(12,3))
sns.set_theme(style="whitegrid")
plt.scatter(merge_df["Average speed (Mbps)"], merge_df["Average latency (ms)"], s=3.5)
plt.xlabel('Download speed (Mbps)')
plt.ylabel('Idle latency rtt_avg (ms)')
plt.show()

# %% [markdown]
# ## Idle latency vs Average upload speed for DSL (Jan 2011 - Jul 2023)

# %%
latency = pd.read_csv("data/Average of Idle latency-DSL.csv")
speed = pd.read_csv("data/Average upload speed-DSL.csv")
merge_df = pd.merge(speed, latency, how="left", on="dtime per week")
merge_df.tail()
# Out:
#     dtime per week  Average speed (Mbps)  Average latency (ms)
# 653     2023-07-03                44.844                31.208
# 654     2023-07-10                45.375                30.913
# 655     2023-07-17                45.642                30.982
# 656     2023-07-24                46.434                31.242
# 657     2023-07-31                47.243                30.571

# %%
plt.figure(figsize=(12,3))
sns.set_theme(style="whitegrid")
plt.scatter(merge_df["Average speed (Mbps)"], merge_df["Average latency (ms)"], s=3.5)
plt.xlabel('Upload speed (Mbps)')
plt.ylabel('Idle latency rtt_avg (ms)')
plt.show()

# %% [markdown]
# ## Downstream LUL vs Average download speed for DSL (Jan 2011 - Jul 2023)

# %%
latency = pd.read_csv("data/Average of downstream LUL-DSL.csv")
speed = pd.read_csv("data/Average download speed-DSL.csv")
merge_df = pd.merge(speed, latency, how="left", on="dtime per week")
merge_df.tail()
# Out:
#     dtime per week  Average speed (Mbps)  Average latency (ms)
# 653     2023-07-03                77.444               125.724
# 654     2023-07-10                78.943               125.169
# 655     2023-07-17                79.936               125.905
# 656     2023-07-24                80.485               129.978
# 657     2023-07-31                82.046               128.913

# %%
plt.figure(figsize=(12,3))
sns.set_theme(style="whitegrid")
plt.scatter(merge_df["Average speed (Mbps)"], merge_df["Average latency (ms)"], s=3.5)
plt.xlabel('Download speed (Mbps)')
plt.ylabel('Downstream LUL rtt_avg (ms)')
plt.show()

# %% [markdown]
# ## Upstream LUL vs Average upload speed for DSL (Jan 2011 - Jul 2023)

# %%
latency = pd.read_csv("data/Average of Upstream LUL-DSL.csv")
speed = pd.read_csv("data/Average upload speed-DSL.csv")
merge_df = pd.merge(speed, latency, how="left", on="dtime per week")
merge_df.tail()
# Out:
#     dtime per week  Average speed (Mbps)  Average latency (ms)
# 653     2023-07-03                44.844               332.829
# 654     2023-07-10                45.375               334.113
# 655     2023-07-17                45.642               335.063
# 656     2023-07-24                46.434               327.453
# 657     2023-07-31                47.243               326.870

# %%
plt.figure(figsize=(12,3))
sns.set_theme(style="whitegrid")
plt.scatter(merge_df["Average speed (Mbps)"], merge_df["Average latency (ms)"], s=3.5)
plt.xlabel('Upload speed (Mbps)')
plt.ylabel('Upstream LUL rtt_avg (ms)')
plt.show()
