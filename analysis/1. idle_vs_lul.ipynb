# %%
from helpers import get_client, get_data

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
es = get_client()  
idle_df = get_data("aggregated-curr-udplatency-*", es)
up_lul = get_data("aggregated-curr-ulping-*", es)
down_lul = get_data("aggregated-curr-dlping-*", es)
# Out:
# Connected to Elasticsearch.

# %% [markdown]
# ```
# Latency-RTT histograms (Idle vs Downstream) – 2023 data
# -------------------------------------------------------
# • One figure for **Overall** plus one per access-technology
#   (column `operator_technology`).
# • Uses only samples whose **date** falls in calendar-year 2023.
# • For every dataset we clip values above its own 95th-percentile.
#   – `idle_q95`, `lul_up_q95`, `lul_down_q95`
# • Histogram bars are a strict **5 ms** wide, and *all* sub-plots
#   share the exact same bin edges and x-axis scale.
# • The two y-axes in each figure are locked to the same percentage
#   range so their shapes are directly comparable.
# ```

# %%
# ------------------------------------------------------------------
# FILTER TO YEAR-2023
# ------------------------------------------------------------------
for _df in (idle_df, up_lul, down_lul):
    _df['date'] = pd.to_datetime(_df['date'])        # ensure datetime dtype

idle_2023 = idle_df [idle_df ['date'].dt.year == 2023].copy()
down_2023 = down_lul[down_lul['date'].dt.year == 2023].copy()

# Month/year span for the plot titles
start_str = min(idle_2023['date'].min(),
                down_2023['date'].min()).strftime('%m/%Y')
end_str   = max(idle_2023['date'].max(),
                down_2023['date'].max()).strftime('%m/%Y')

# ------------------------------------------------------------------
# GLOBAL 95th-PERCENTILE THRESHOLDS & BIN EDGES
# ------------------------------------------------------------------
bin_width = 5  # ms

idle_q95     = idle_2023['rtt_avg'].quantile(0.95)
lul_down_q95 = down_2023['rtt_avg'].quantile(0.95)

lo = np.floor(
        min(idle_2023['rtt_avg'].min(),
            down_2023['rtt_avg'].min()) / bin_width
     ) * bin_width
hi = np.ceil(
        max(idle_q95, lul_down_q95) / bin_width
     ) * bin_width

edges = np.arange(lo, hi + bin_width, bin_width)   # inclusive upper edge

# ------------------------------------------------------------------
# LOOP OVER 'Overall' + EACH TECHNOLOGY
# ------------------------------------------------------------------
tech_list = ['Overall', 'DSL', 'Cable', 'Fiber']

for tech in tech_list:
    # ------------- subset rows -----------------------------------
    if tech == 'Overall':
        idle_tmp = idle_2023
        down_tmp = down_2023
    else:
        idle_tmp = idle_2023[idle_2023['operator_technology'] == tech]
        down_tmp = down_2023[down_2023['operator_technology'] == tech]

    # ------------- clip to global 95th percentile -----------------
    idle_clipped = idle_tmp.loc[idle_tmp['rtt_avg'] <= idle_q95, 'rtt_avg']
    down_clipped = down_tmp.loc[down_tmp['rtt_avg'] <= lul_down_q95, 'rtt_avg']

    # --- if both are empty there’s nothing to show; skip ----------
    if idle_clipped.empty and down_clipped.empty:
        print(f'Skipping {tech}: no data inside 95th-percentile threshold')
        continue

    # ------------- figure & axes ---------------------------------
    fig, (ax_top, ax_bottom) = plt.subplots(
        2, 1, figsize=(10, 6), sharex=True,
        gridspec_kw={'height_ratios': [1, 1], 'hspace': 0}
    )

    # ------------- top histogram (Idle latency) ------------------
    if not idle_clipped.empty:
        sns.histplot(
            idle_clipped, bins=edges, stat='percent',
            alpha=0.7, color='skyblue', edgecolor='black',
            ax=ax_top, label='Idle Latency (ms)'
        )
    ax_top.grid(True, axis='y', ls='--', alpha=.4)
    ax_top.spines['bottom'].set_visible(False)
    ax_top.tick_params(axis='x', bottom=False, labelbottom=False)
    ax_top.set_ylabel('')

    # ------------- bottom histogram (Downstream latency) ---------
    if not down_clipped.empty:
        sns.histplot(
            down_clipped, bins=edges, stat='percent',
            alpha=0.7, color='#f48120', edgecolor='black',
            ax=ax_bottom, label='Downstream Latency (ms)'
        )
    ax_bottom.invert_yaxis()
    ax_bottom.grid(True, axis='y', ls='--', alpha=.4)
    ax_bottom.spines['top'].set_visible(False)
    ax_bottom.set_xlabel('')
    ax_bottom.set_ylabel('')

    # ------------- lock y-ranges safely --------------------------
    # --- compute the maximum % so we can force both axes to the same limits
    heights_top  = [p.get_height() for p in ax_top.patches]
    heights_bot  = [p.get_height() for p in ax_bottom.patches]
    max_up   = max(heights_top) if heights_top else 0
    max_down = max(heights_bot) if heights_bot else 0
    y_max = max(max_up, max_down, 1)      # fallback to 1% so it's never flat

    # --- force identical y‐limits
    ax_top.set_ylim(0, y_max)
    ax_bottom.set_ylim(y_max, 0)      

    tick_step = 5
    yticks = np.arange(0, y_max + tick_step, tick_step)

    ax_top.set_yticks(yticks)
    ax_bottom.set_yticks(yticks)


    # ------------- shared labels & legend ------------------------
    fig.text(0.5, 0, 'RTT Average (ms)', ha='center', va='top')
    fig.text(-0.01, 0.5, 'Percentage of samples (%)',
             ha='center', va='center', rotation='vertical')

    handles_top, labels_top = ax_top.get_legend_handles_labels()
    handles_bottom, labels_bottom = ax_bottom.get_legend_handles_labels()
    fig.legend(
        handles_top + handles_bottom,
        labels_top  + labels_bottom,
        loc='upper right',
        bbox_to_anchor=(0.98, 0.91),
        title='Bin width = 5 ms'
    )

    plt.suptitle(
        f'Distribution of Idle vs Latency under Load (Downstream) (≤95th pct) – {tech} '
        f'[{start_str} – {end_str}]'
    )
    plt.tight_layout()
    fname = (
        './plots/latency/idle_vs_downstream/'
        f'idle_vs_downstream_latency_{tech.lower().replace(" ", "_")}.png'
    )
    plt.savefig(fname, dpi=600, bbox_inches='tight')
    plt.show()

# %%
# ------------------------------------------------------------------
# FILTER TO YEAR-2023
# ------------------------------------------------------------------

idle_2023 = idle_df [idle_df ['date'].dt.year == 2023].copy()
up_2023 = up_lul[up_lul['date'].dt.year == 2023].copy()

# Month/year span for the plot titles
start_str = min(idle_2023['date'].min(),
                up_2023['date'].min()).strftime('%m/%Y')
end_str   = max(idle_2023['date'].max(),
                up_2023['date'].max()).strftime('%m/%Y')

# ------------------------------------------------------------------
# GLOBAL 95th-PERCENTILE THRESHOLDS & BIN EDGES
# ------------------------------------------------------------------
bin_width = 5  # ms

idle_q95     = idle_2023['rtt_avg'].quantile(0.95)
lul_up_q95   = up_2023['rtt_avg'].quantile(0.95)
 
lo = np.floor(
        min(idle_2023['rtt_avg'].min(),
            up_2023['rtt_avg'].min()) / bin_width
     ) * bin_width
hi = np.ceil(
        max(idle_q95, lul_up_q95) / bin_width
     ) * bin_width

edges = np.arange(lo, hi + bin_width, bin_width)   # inclusive upper edge

# ------------------------------------------------------------------
# LOOP OVER 'Overall' + EACH TECHNOLOGY
# ------------------------------------------------------------------
tech_list = ['Overall', 'DSL', 'Cable', 'Fiber']

for tech in tech_list:
    # ------------- subset rows -----------------------------------
    if tech == 'Overall':
        idle_tmp = idle_2023
        up_tmp = up_2023
    else:
        idle_tmp = idle_2023[idle_2023['operator_technology'] == tech]
        up_tmp = up_2023[up_2023['operator_technology'] == tech]

    # ------------- clip to global 95th percentile -----------------
    idle_clipped = idle_tmp.loc[idle_tmp['rtt_avg'] <= idle_q95, 'rtt_avg']
    up_clipped = up_tmp.loc[up_tmp['rtt_avg'] <= lul_up_q95, 'rtt_avg']

    # --- if both are empty there’s nothing to show; skip ----------
    if idle_clipped.empty and up_clipped.empty:
        print(f'Skipping {tech}: no data inside 95th-percentile threshold')
        continue

    # ------------- figure & axes ---------------------------------
    fig, (ax_top, ax_bottom) = plt.subplots(
        2, 1, figsize=(10, 6), sharex=True,
        gridspec_kw={'height_ratios': [1, 1], 'hspace': 0}
    )

    # ------------- top histogram (Idle latency) ------------------
    if not idle_clipped.empty:
        sns.histplot(
            idle_clipped, bins=edges, stat='percent',
            alpha=0.7, color='skyblue', edgecolor='black',
            ax=ax_top, label='Idle Latency (ms)'
        )
    ax_top.grid(True, axis='y', ls='--', alpha=.4)
    ax_top.spines['bottom'].set_visible(False)
    ax_top.tick_params(axis='x', bottom=False, labelbottom=False)
    ax_top.set_ylabel('')

    # ------------- bottom histogram (Downstream latency) ---------
    if not up_clipped.empty:
        sns.histplot(
            up_clipped, bins=edges, stat='percent',
            alpha=0.7, color='#f48120', edgecolor='black',
            ax=ax_bottom, label='Upstream Latency (ms)'
        )
    ax_bottom.invert_yaxis()
    ax_bottom.grid(True, axis='y', ls='--', alpha=.4)
    ax_bottom.spines['top'].set_visible(False)
    ax_bottom.set_xlabel('')
    ax_bottom.set_ylabel('')

    # ------------- lock y-ranges safely --------------------------
    # --- compute the maximum % so we can force both axes to the same limits
    heights_top  = [p.get_height() for p in ax_top.patches]
    heights_bot  = [p.get_height() for p in ax_bottom.patches]
    max_up   = max(heights_top) if heights_top else 0
    max_down = max(heights_bot) if heights_bot else 0
    y_max = max(max_up, max_down, 1)     

    ax_top.set_ylim(0, y_max)
    ax_bottom.set_ylim(y_max, 0)      

    tick_step = 5
    yticks = np.arange(0, y_max + tick_step, tick_step)

    ax_top.set_yticks(yticks)
    ax_bottom.set_yticks(yticks)


    # ------------- shared labels & legend ------------------------
    fig.text(0.5, 0, 'RTT Average (ms)', ha='center', va='top')
    fig.text(-0.01, 0.5, 'Percentage of samples (%)',
             ha='center', va='center', rotation='vertical')

    handles_top, labels_top = ax_top.get_legend_handles_labels()
    handles_bottom, labels_bottom = ax_bottom.get_legend_handles_labels()
    fig.legend(
        handles_top + handles_bottom,
        labels_top  + labels_bottom,
        loc='upper right',
        bbox_to_anchor=(0.98, 0.91),
        title='Bin width = 5 ms'
    )

    plt.suptitle(
        f'Distribution of Idle vs Latency under Load (Upstream) (≤95th pct) – {tech} '
        f'[{start_str} – {end_str}]'
    )
    plt.tight_layout()
    fname = (
        './plots/latency/idle_vs_upstream/'
        f'idle_vs_upstream_latency_{tech.lower().replace(" ", "_")}.png'
    )
    plt.savefig(fname, dpi=600, bbox_inches='tight')
    plt.show()

# %%
# global 95th-percentile thresholds & bin edges
bin_width = 5  # ms
idle_q95     = idle_2023['rtt_avg'].quantile(0.95)
lul_down_q95 = down_2023['rtt_avg'].quantile(0.95)

lo = (np.floor(min(idle_2023['rtt_avg'].min(),
                   down_2023['rtt_avg'].min()) / bin_width)
      * bin_width)
hi = (np.ceil(max(idle_q95, lul_down_q95) / bin_width)
      * bin_width)
edges = np.arange(lo, hi + bin_width, bin_width)

# determine month/year span for overall suptitle
start_str = min(idle_2023['date'].min(), down_2023['date'].min()).strftime('%m/%Y')
end_str   = max(idle_2023['date'].max(), down_2023['date'].max()).strftime('%m/%Y')

tech_list = ['Overall', 'DSL', 'Cable', 'Fiber']

# --- create one figure with 2x2 subplots, share x and y among all ---
fig, axes = plt.subplots(2, 2, figsize=(12, 8), sharex=True, sharey=True)
axes = axes.flatten()

for ax, tech in zip(axes, tech_list):
    # subset
    if tech == 'Overall':
        idle_tmp = idle_2023
        down_tmp = down_2023
    else:
        idle_tmp = idle_2023[idle_2023['operator_technology'] == tech]
        down_tmp = down_2023[down_2023['operator_technology'] == tech]

    # clip to respective 95th pct
    idle_clip = idle_tmp[idle_tmp['rtt_avg'] <= idle_q95]['rtt_avg']
    down_clip = down_tmp[down_tmp['rtt_avg'] <= lul_down_q95]['rtt_avg']

    # plot both on the same axes
    if not idle_clip.empty:
        sns.histplot(idle_clip, bins=edges, stat='percent', kde=True,
                     alpha=0.6, edgecolor='black',
                     label='Idle', ax=ax)
    if not down_clip.empty:
        sns.histplot(down_clip, bins=edges, stat='percent', kde=True,
                     alpha=0.6, edgecolor='black',
                     label='Downstream', ax=ax)

    ax.set_title(tech)
    ax.grid(axis='y', linestyle='--', alpha=0.4)
    ax.set_xlabel('RTT Avg (ms)')
    ax.set_ylabel('Percent (%)')
    ax.legend(title=f'Bin={bin_width}ms') 

# global figure tweaks
fig.suptitle(f'Idle vs Latency under Load (Downstream) (≤95th pct) [{start_str}–{end_str}]', y=0.92)
fig.tight_layout(rect=[0, 0, 1, 0.93])
plt.savefig('./plots/latency/idle_vs_downstream/idle_vs_downstream_latency_consolidated.png',
            dpi=600, bbox_inches='tight')
plt.show()

# %%
# global 95th-percentile thresholds & bin edges
bin_width = 5  # ms
idle_q95     = idle_2023['rtt_avg'].quantile(0.95)
lul_up_q95   = up_2023['rtt_avg'].quantile(0.95)

lo = (np.floor(min(idle_2023['rtt_avg'].min(),
                   up_2023['rtt_avg'].min()) / bin_width)
      * bin_width)
hi = (np.ceil(max(idle_q95, lul_up_q95) / bin_width)
      * bin_width)
edges = np.arange(lo, hi + bin_width, bin_width)

# determine month/year span for overall suptitle
start_str = min(idle_2023['date'].min(), up_2023['date'].min()).strftime('%m/%Y')
end_str   = max(idle_2023['date'].max(), up_2023['date'].max()).strftime('%m/%Y')

tech_list = ['Overall', 'DSL', 'Cable', 'Fiber']

# --- create one figure with 2x2 subplots, share x and y among all ---
fig, axes = plt.subplots(2, 2, figsize=(12, 8), sharex=True, sharey=True)
axes = axes.flatten()

for ax, tech in zip(axes, tech_list):
    # subset
    if tech == 'Overall':
        idle_tmp = idle_2023
        up_tmp = up_2023
    else:
        idle_tmp = idle_2023[idle_2023['operator_technology'] == tech]
        up_tmp = up_2023[up_2023['operator_technology'] == tech]

    # clip to respective 95th pct
    idle_clip = idle_tmp[idle_tmp['rtt_avg'] <= idle_q95]['rtt_avg']
    up_clip = up_tmp[up_tmp['rtt_avg'] <= lul_up_q95]['rtt_avg']

    # plot both on the same axes
    if not idle_clip.empty:
        sns.histplot(idle_clip, bins=edges, stat='percent', kde=True,
                     alpha=0.6, edgecolor='black',
                     label='Idle', ax=ax)
    if not up_clip.empty:
        sns.histplot(up_clip, bins=edges, stat='percent', kde=True,
                     alpha=0.6, edgecolor='black',
                     label='Downstream', ax=ax)

    ax.set_title(tech)
    ax.grid(axis='y', linestyle='--', alpha=0.4)
    ax.set_xlabel('RTT Avg (ms)')
    ax.set_ylabel('Percent (%)')
    ax.legend(title=f'Bin={bin_width}ms')  

# global figure tweaks
fig.suptitle(f'Idle vs Latency under Load (Upstream) (≤95th pct) [{start_str}–{end_str}]', y=0.92)
fig.tight_layout(rect=[0, 0, 1, 0.93])
plt.savefig('./plots/latency/idle_vs_upstream/idle_vs_upstream_latency_consolidated.png',
            dpi=600, bbox_inches='tight')
plt.show()
